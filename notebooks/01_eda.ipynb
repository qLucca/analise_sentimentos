# %%
import pandas as pd

unified_path = r"../data/gold/dashboard/unified_dataset.csv"
df_unified = pd.read_csv(unified_path, encoding="utf-8")

df_unified["data_publicacao"] = pd.to_datetime(df_unified["data_publicacao"], errors="coerce")

print(df_unified.shape)
print(df_unified.head())
# Out:
# (178467, 10)
#                             id_registro        fonte data_publicacao titulo  \
# 0  8696d55a-a22a-4f5b-b62c-746b4138ae27  google_play      2026-03-31    NaN
# 1  f9ba1b10-d191-412a-b6f6-5b4f6154a9e6  google_play      2026-03-31    NaN
# 2  0c72b5e1-e4a7-4cea-9b6f-5a99a72898bc  google_play      2026-03-31    NaN
# 3  98eb1147-e329-40ee-ad75-f5ea4fe9c920  google_play      2026-03-31    NaN
# 4  9dcfa4ed-2be1-4942-831e-f1afb340f19e  google_play      2026-03-31    NaN
#
#                                       texto_original  nota usuario categoria  \
# 0        Amo o Nubank! Ótima experiência. Gratidão 🙏   5.0     NaN       NaN
# 1  porque não dá oportunidade de crédito deu uma ...   2.0     NaN       NaN
# 2                Muito bom não tenho nada a reclamar   5.0     NaN       NaN
# 3                               não tenho limite bom   1.0     NaN       NaN
# 4                                              OTIMA   5.0     NaN       NaN
#
#   status sentimento_real
# 0    NaN        Positivo
# 1    NaN        Negativo
# 2    NaN        Positivo
# 3    NaN        Negativo
# 4    NaN        Positivo

# %%
print(df_unified["fonte"].value_counts())
print(df_unified["fonte"].value_counts(normalize=True) * 100)
# Out:
# fonte
# consumidor_gov    125636
# google_play        38948
# youtube            13883
# Name: count, dtype: int64
# fonte
# consumidor_gov    70.397328
# google_play       21.823642
# youtube            7.779029
# Name: proportion, dtype: float64

# %%
print(
    df_unified.groupby("fonte")["data_publicacao"]
    .agg(["min", "max", "count"])
)
# Out:
#                       min        max   count
# fonte
# consumidor_gov 2025-08-22 2026-03-31  125636
# google_play    2025-10-01 2026-03-31   38948
# youtube        2025-10-01 2026-03-31   13883

# %%
print((df_unified.notna().mean() * 100).sort_values(ascending=False))
# Out:
# id_registro        100.000000
# fonte              100.000000
# data_publicacao    100.000000
# titulo              78.176358
# categoria           78.176358
# status              70.397328
# nota                35.223319
# texto_original      29.600991
# sentimento_real     21.823642
# usuario              7.779029
# dtype: float64

# %%
print(df_unified["sentimento_real"].value_counts(dropna=False))
# Out:
# sentimento_real
# NaN         139519
# Positivo     29520
# Negativo      7872
# Neutro        1556
# Name: count, dtype: int64

# %%
print(df_unified["nota"].describe())
print(df_unified["nota"].value_counts(dropna=False).sort_index())
# Out:
# count    62862.000000
# mean         3.202587
# std          1.848001
# min          1.000000
# 25%          1.000000
# 50%          4.000000
# 75%          5.000000
# max          5.000000
# Name: nota, dtype: float64
# nota
# 1.0     23065
# 2.0      3439
# 3.0      3681
# 4.0      3050
# 5.0     29627
# NaN    115605
# Name: count, dtype: int64

# %%
textual_path = r"../data/sandbox/notebooks/textual_dataset.csv"
df_textual = pd.read_csv(textual_path, encoding="utf-8")

df_textual["data_publicacao"] = pd.to_datetime(df_textual["data_publicacao"], errors="coerce")

print(df_textual.shape)
print(df_textual.head())
# Out:
# (52828, 10)
#                             id_registro        fonte data_publicacao titulo  \
# 0  8696d55a-a22a-4f5b-b62c-746b4138ae27  google_play      2026-03-31    NaN
# 1  f9ba1b10-d191-412a-b6f6-5b4f6154a9e6  google_play      2026-03-31    NaN
# 2  0c72b5e1-e4a7-4cea-9b6f-5a99a72898bc  google_play      2026-03-31    NaN
# 3  98eb1147-e329-40ee-ad75-f5ea4fe9c920  google_play      2026-03-31    NaN
# 4  9dcfa4ed-2be1-4942-831e-f1afb340f19e  google_play      2026-03-31    NaN
#
#                                       texto_original  nota usuario categoria  \
# 0        Amo o Nubank! Ótima experiência. Gratidão 🙏   5.0     NaN       NaN
# 1  porque não dá oportunidade de crédito deu uma ...   2.0     NaN       NaN
# 2                Muito bom não tenho nada a reclamar   5.0     NaN       NaN
# 3                               não tenho limite bom   1.0     NaN       NaN
# 4                                              OTIMA   5.0     NaN       NaN
#
#    status sentimento_real
# 0     NaN        Positivo
# 1     NaN        Negativo
# 2     NaN        Positivo
# 3     NaN        Negativo
# 4     NaN        Positivo

# %%
print(df_textual["fonte"].value_counts())
print(df_textual["fonte"].value_counts(normalize=True) * 100)
# Out:
# fonte
# google_play    38948
# youtube        13880
# Name: count, dtype: int64
# fonte
# google_play    73.726054
# youtube        26.273946
# Name: proportion, dtype: float64

# %%
df_textual["tamanho_texto"] = df_textual["texto_original"].astype(str).str.len()

print(df_textual["tamanho_texto"].describe())
# Out:
# count    52828.000000
# mean        70.880045
# std        117.469493
# min          1.000000
# 25%         11.000000
# 50%         34.000000
# 75%         85.000000
# max       4497.000000
# Name: tamanho_texto, dtype: float64

# %%
print(
    df_textual.groupby("fonte")["tamanho_texto"]
    .agg(["mean", "median", "min", "max"])
)
# Out:
#                    mean  median  min   max
# fonte
# google_play   57.921947    25.0    1   500
# youtube      107.241138    65.0    1  4497

# %%
df_textual["ano_mes"] = df_textual["data_publicacao"].dt.to_period("M")

print(df_textual["ano_mes"].value_counts().sort_index())
# Out:
# ano_mes
# 2025-10    7913
# 2025-11    7835
# 2025-12    8816
# 2026-01    9409
# 2026-02    9298
# 2026-03    9557
# Freq: M, Name: count, dtype: int64

# %%
print(df_textual["sentimento_real"].value_counts(dropna=False))
# Out:
# sentimento_real
# Positivo    29520
# NaN         13880
# Negativo     7872
# Neutro       1556
# Name: count, dtype: int64

# %%
print(df_textual["texto_original"].sample(10, random_state=42).tolist())
# Out:
# ['tô tentando entrar na minha conta mais diz que o cepf tá inválido ele não tá', 'Que esses canalhas paguem por todas as falcatruas que cometeram!', 'muito bom 👍', 'estou desinstalando o app , por motivos que trancaram meu saldo de emergência , e o dinheiro vai fazer falta!', 'Há anos tenho conta nessa instituição e o atendimento só piora. E não há profissionais competentes e capacitados para resolução de um problema. Para classificar a Nubank como ruim, eles têm que melhorar bastante. É surreal a forma que o cliente é tratado e desdenhado.', 'Nubank de 30 em 30 dias', 'Dobraram meu limite no cartão esses dias atrás. Nao paga anuidade no cartão. Vc bloqueia a leitura por toque. Aumenta e diminui o limite pra evitar golpe na maquininha.', 'portabilidade de salario  ha 2 meses  salário de 3 mil e cartão de crédito so de 200 reais', 'Banco muito bom, apenas o limite de crédito e baixo, menor que limite para CPF, vou direcionar meus pagamentos pra ver se melhora as minhas opções de crédito , hoje não me atende , meu crédito acaba em dois dias só com compras básicas , nem o mercantil da para comprar', 'boa']

# %%
df_gp = df_unified[df_unified["fonte"] == "google_play"].copy()

print(pd.crosstab(df_gp["nota"], df_gp["sentimento_real"]))
# Out:
# sentimento_real  Negativo  Neutro  Positivo
# nota
# 1.0                  6476       0         0
# 2.0                  1396       0         0
# 3.0                     0    1556         0
# 4.0                     0       0      2149
# 5.0                     0       0     27371

# %%
print(
    df_unified.groupby("fonte")["texto_original"]
    .apply(lambda s: s.notna().sum())
)
# Out:
# fonte
# consumidor_gov        0
# google_play       38948
# youtube           13880
# Name: texto_original, dtype: int64

# %%
df_youtube = pd.read_csv(r'../data/raw/youtube/nubank_youtube_comments.csv', encoding="utf-8")
print(df_youtube[["data_publicacao"]].head(10))
print(df_youtube["data_publicacao"].dtype)
# Out:
#   data_publicacao
# 0      2026-03-31
# 1      2026-03-31
# 2      2026-03-31
# 3      2026-03-31
# 4      2026-03-31
# 5      2026-03-31
# 6      2026-03-31
# 7      2026-03-31
# 8      2026-03-31
# 9      2026-03-31
# str

# %%
print(
    df_textual.groupby("fonte")["data_publicacao"]
    .agg(["min", "max", "count"])
)
# Out:
#                    min        max  count
# fonte
# google_play 2025-10-01 2026-03-31  38948
# youtube     2025-10-01 2026-03-31  13880

# %%
print(
    df_textual.groupby(["fonte", "ano_mes"])
    .size()
)
# Out:
# fonte        ano_mes
# google_play  2025-10    6774
#              2025-11    6154
#              2025-12    6913
#              2026-01    5860
#              2026-02    6877
#              2026-03    6370
# youtube      2025-10    1139
#              2025-11    1681
#              2025-12    1903
#              2026-01    3549
#              2026-02    2421
#              2026-03    3187
# dtype: int64

# %%
df_cg = df_unified[df_unified["fonte"] == "consumidor_gov"].copy()
print(df_cg["categoria"].value_counts().head(20))
# Out:
# categoria
# Cobrança / Contestação          111350
# Atendimento / SAC                 5298
# Dados Pessoais e Privacidade      3084
# Vício de Qualidade                2828
# Contrato / Oferta                 2672
# Informação                         279
# Entrega do Produto                  67
# Saúde e Segurança                   58
# Name: count, dtype: int64

# %%
print(
    df_unified.groupby("fonte")["data_publicacao"]
    .agg(["min", "max", "count"])
)

print(
    df_textual.groupby("fonte")["data_publicacao"]
    .agg(["min", "max", "count"])
)
# Out:
#                       min        max   count
# fonte
# consumidor_gov 2025-08-22 2026-03-31  125636
# google_play    2025-10-01 2026-03-31   38948
# youtube        2025-10-01 2026-03-31   13883
#                    min        max  count
# fonte
# google_play 2025-10-01 2026-03-31  38948
# youtube     2025-10-01 2026-03-31  13880

# %%
import pandas as pd

df = pd.read_csv(
    r"../data/silver/preprocessing/textual_dataset_preprocessed.csv",
    encoding="utf-8"
)

print(df.shape)
print(df.columns.tolist())
print(df.head())
print(df[["texto_original", "texto_limpo"]].head(10))
# Out:
# (52408, 12)
# ['id_registro', 'fonte', 'data_publicacao', 'titulo', 'texto_original', 'nota', 'usuario', 'categoria', 'status', 'sentimento_real', 'texto_limpo', 'data_processamento']
#                             id_registro        fonte data_publicacao titulo  \
# 0  8696d55a-a22a-4f5b-b62c-746b4138ae27  google_play      2026-03-31    NaN
# 1  f9ba1b10-d191-412a-b6f6-5b4f6154a9e6  google_play      2026-03-31    NaN
# 2  0c72b5e1-e4a7-4cea-9b6f-5a99a72898bc  google_play      2026-03-31    NaN
# 3  98eb1147-e329-40ee-ad75-f5ea4fe9c920  google_play      2026-03-31    NaN
# 4  9dcfa4ed-2be1-4942-831e-f1afb340f19e  google_play      2026-03-31    NaN
#
#                                       texto_original  nota usuario categoria  \
# 0        Amo o Nubank! Ótima experiência. Gratidão 🙏   5.0     NaN       NaN
# 1  porque não dá oportunidade de crédito deu uma ...   2.0     NaN       NaN
# 2                Muito bom não tenho nada a reclamar   5.0     NaN       NaN
# 3                               não tenho limite bom   1.0     NaN       NaN
# 4                                              OTIMA   5.0     NaN       NaN
#
#    status sentimento_real                                    texto_limpo  \
# 0     NaN        Positivo          amo nubank otima experiencia gratidao
# 1     NaN        Negativo  porque nao oportunidade credito deu vez tchau
# 2     NaN        Positivo              muito bom nao tenho nada reclamar
# 3     NaN        Negativo                           nao tenho limite bom
# 4     NaN        Positivo                                          otima
#
#            data_processamento
# 0  2026-05-24 11:05:27.119859
# 1  2026-05-24 11:05:27.119859
# 2  2026-05-24 11:05:27.119859
# 3  2026-05-24 11:05:27.119859
# 4  2026-05-24 11:05:27.119859
#                                       texto_original  \
# 0        Amo o Nubank! Ótima experiência. Gratidão 🙏
# 1  porque não dá oportunidade de crédito deu uma ...
# 2                Muito bom não tenho nada a reclamar
# 3                               não tenho limite bom
# 4                                              OTIMA
# 5                                           o melhor
# 6   é um ótimo banco um banco bem confiável e seguro
# 7      to gostando do atendimento muito bom valeu? 😃
# 8  Nubank e Bom Mas Tem MT Frescura Com NGC De En...
# 9  péssimo. estou com uma quantia de dinheiro na ...
#
#                                          texto_limpo
# 0              amo nubank otima experiencia gratidao
# 1      porque nao oportunidade credito deu vez tchau
# 2                  muito bom nao tenho nada reclamar
# 3                               nao tenho limite bom
# 4                                              otima
# 5                                             melhor
# 6             otimo banco banco bem confiavel seguro
# 7            to gostando atendimento muito bom valeu
# 8  nubank bom tem mt frescura ngc enviar transfer...
# 9  pessimo estou quantia dinheiro conta nao estao...

# %%
import pandas as pd
from collections import Counter

df = pd.read_csv(
    r"../data/silver/preprocessing/textual_dataset_preprocessed.csv",
    encoding="utf-8"
)

df["qtd_palavras"] = df["texto_limpo"].astype(str).str.split().str.len()

print(df.shape)
print(df["fonte"].value_counts())
print(df["qtd_palavras"].describe())
print(df["sentimento_real"].value_counts(dropna=False))
print(df["texto_limpo"].sample(10, random_state=42).tolist())
# Out:
# (52408, 13)
# fonte
# google_play    38698
# youtube        13710
# Name: count, dtype: int64
# count    52408.000000
# mean         8.940181
# std         13.344148
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%         11.000000
# max        470.000000
# Name: qtd_palavras, dtype: float64
# sentimento_real
# Positivo    29292
# NaN         13710
# Negativo     7858
# Neutro       1548
# Name: count, dtype: int64
# ['muito ruim juros altos nao aumenta limite', 'otimo', 'ai01', 'bmg', 'melhor', 'bom dia sou clt tbm mei final contas renda dois serao somadas cada pessoa pessoa', 'segunda conta q tive vida tenho 46 anos parese tudo mais simples', 'pena canal mudou tinham melhor', 'tenho cartao marido quer tambem ele nao tem celular devo fazer pra ele ter cartao dele posso baixar celular dele tambem', 'otimo']

# %%
tokens = " ".join(df["texto_limpo"].astype(str)).split()
freq = Counter(tokens)
print(freq.most_common(30))
# Out:
# [('nao', 15773), ('muito', 12604), ('bom', 10177), ('banco', 7808), ('nubank', 6948), ('mais', 5195), ('otimo', 5152), ('conta', 5148), ('pra', 5081), ('app', 4530), ('aplicativo', 4288), ('cartao', 4014), ('so', 3613), ('tem', 3542), ('tenho', 3021), ('melhor', 2976), ('estou', 2810), ('limite', 2798), ('dinheiro', 2702), ('credito', 2519), ('excelente', 2118), ('fazer', 2097), ('nada', 2035), ('ta', 2006), ('tudo', 1903), ('mesmo', 1795), ('ate', 1773), ('agora', 1724), ('consigo', 1715), ('ele', 1689)]

# %%
for fonte in df["fonte"].unique():
    tokens_fonte = " ".join(df.loc[df["fonte"] == fonte, "texto_limpo"].astype(str)).split()
    freq_fonte = Counter(tokens_fonte)
    print(f"\nFonte: {fonte}")
    print(freq_fonte.most_common(20))
# Out:
# Fonte: google_play
# [('muito', 11462), ('nao', 10753), ('bom', 9591), ('banco', 5228), ('otimo', 5017), ('app', 4327), ('aplicativo', 4127), ('nubank', 4005), ('conta', 3342), ('mais', 3331), ('pra', 2865), ('cartao', 2845), ('melhor', 2438), ('estou', 2249), ('so', 2057), ('excelente', 2014), ('limite', 1952), ('tem', 1928), ('credito', 1759), ('tenho', 1616)]
#
# Fonte: youtube
# [('nao', 5020), ('nubank', 2943), ('banco', 2580), ('pra', 2216), ('mais', 1864), ('conta', 1806), ('tem', 1614), ('so', 1556), ('tenho', 1405), ('dinheiro', 1404), ('cartao', 1169), ('muito', 1142), ('vai', 986), ('emprestimo', 954), ('limite', 846), ('mil', 838), ('eles', 824), ('reais', 761), ('credito', 760), ('nada', 728)]
